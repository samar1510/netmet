# %%
# Create a world map to show distributions of users
import folium
from folium.plugins import MarkerCluster

from common.default import TP1_ANCHORS_PATH, TP1_PROBES_PATH, TP1_RESULTS_PATH
from common.file_utils import load_json

ANCHOR_RADIUS = 0.2
PROBES_RADIUS = 0.1


def set_folium_marker(coordinates: list, radius: int, map: folium.Map) -> None:
    """get list of coordinates set marker on folium map"""
    for coordinate in coordinates:
        lat = coordinate[1]
        lon = coordinate[0]

        folium.Marker(location=[lat, lon], radius=radius, fill=True).add_to(map)

# folium.Marker(
#     location=[45.3311, -121.7113],
#     tooltip="Click me!",
#     popup="Timberline Lodge",
#     icon=folium.Icon(color="green"),
# ).add_to(m)

# probes = load_json(TP1_PROBES_PATH)
anchors = load_json(TP1_ANCHORS_PATH)

# empty map
ripe_atlas_map = folium.Map(tiles="cartodb positron")

anchors_coordinates = [anchor["geometry"]["coordinates"] for anchor in anchors]
set_folium_marker(anchors_coordinates, ANCHOR_RADIUS, ripe_atlas_map)

# probe_coordinates = [probe["geometry"]["coordinates"] for probe in probes]
# set_folium_marker(probe_coordinates, PROBES_RADIUS, ripe_atlas_map)

ripe_atlas_map.save(TP1_RESULTS_PATH / "ripe_atlas_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_070d3f73978b3c074e21b0b6982b1df6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_070d3f73978b3c074e21b0b6982b1df6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_070d3f73978b3c074e21b0b6982b1df6 = L.map(
#                 &quot;map_070d3f73978b3c074e21b0b6982b1df6&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91c55c549180975e0f249a4f57d9d971 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_ed1baa3efc39a65f9e207c80d46e1fb6 = L.marker(
#                 [52.3775, 4.8975],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_d9b6a86e236b0f81dbd7823dfb1c3d24 = L.marker(
#                 [59.9385, 10.8375],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_1bb4154c65982e66d8f3536c906f3d61 = L.marker(
#                 [61.4985, 23.7575],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_1d779a3ae4146436ced3e9e9176787ca = L.marker(
#                 [48.8595, 2.3475],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_8f3aa498b7f6287b7b780c49000c22f1 = L.marker(
#                 [47.3695, 8.5375],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_3885bbddbd18504036dbb203a0ad7461 = L.marker(
#                 [50.0805, 14.4375],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_b99b858c581b112cc89aa3b676fad064 = L.marker(
#                 [53.3205, -6.4425],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_0a7ea3ca08b4490a4b0723601a009c8a = L.marker(
#                 [48.7415, 19.1475],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_907066e3de889e96960eb4960973639a = L.marker(
#                 [48.2115, 16.3675],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_241cbf35ea87a219a6505354820c7dd4 = L.marker(
#                 [42.3875, -71.1525],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_0ea7f14e181dd3c5dec94e96ab9faa6a = L.marker(
#                 [45.0875, 7.6575],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_a7184e6950c92b678ba82ccae9a4f5e9 = L.marker(
#                 [53.5495, 10.0475],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_bb2b0fea7473b3ba7db54e5a13673cfa = L.marker(
#                 [47.3795, 8.5475],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_0554187974c210446276042357010fe6 = L.marker(
#                 [49.5005, 5.9475],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_f719d34810e25d883da27f11db57091b = L.marker(
#                 [52.5005, 13.3975],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_b76601d1c0e13d5db28cd09699ccc00e = L.marker(
#                 [52.3015, 4.9375],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 0.2}
#             ).addTo(map_070d3f73978b3c074e21b0b6982b1df6);
#
#
#             var marker_b1c39d841cb6dfe6168df7
